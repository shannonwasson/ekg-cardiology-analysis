# %%
# smoke test

rec = wfdb.rdrecord('../data/raw/100')
sig = rec.p_signal[:,0]
fs = rec.fs
plt.plot(sig[:1000])
plt.show()

# %% [markdown]
# #datapath
#
# import os
#
# PROJECT_ROOT = os.path.abspath('..')  # go up from notebooks/
# DATA_PATH = os.path.join(PROJECT_ROOT, 'data', 'raw')
#
# rec = wfdb.rdrecord(os.path.join(DATA_PATH, '100'))
